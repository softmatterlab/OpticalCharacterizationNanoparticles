# %% [markdown]
# # Example 1 - Detection and quantification in Brightfield
#
# xxx

# %% [markdown]
# ## 1. Imports

# %%
import sys
sys.path.insert(0, "../") # Adds the module to path
import deeptrack as dt

# %%
import deeplay as dl
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Detection in brightfield
#
# xxx

# %%
data = np.load("../data/brightfield_data.npy")
labels = np.load("../data/brightfield_labels.npy")

# %%
#Subtracting mean in the real part so that the data is centered
data[...,0] = data[...,0] - 1

# %%
plt.figure(figsize=(10,6))
plt.subplot(121)
plt.imshow(data[...,0], cmap="gray")
plt.title("Brightfield data (real part)")
plt.subplot(122)
plt.imshow(data[...,1], cmap="gray")
plt.title("Brightfield data (imaginary part)")
plt.show()

# %%
#Subplot of the distribution of the labels
plt.figure(figsize=(8,3))
plt.subplot(131)
plt.hist(labels[:,2], bins=20, color = 'darkblue')
plt.title("Z-position (in pixels)")
plt.subplot(132)
plt.hist(labels[:,3]*1e9, bins=20, color = 'darkblue', range=(20, 200))
plt.title("Radius(nm)")
plt.subplot(133)
plt.hist(labels[:,4], bins=20, color = 'darkblue', range=(1.35, 1.62))
plt.title("Refractive index")
plt.show()

# %% [markdown]
# ### 2.1 Detecting particles using a classical method

# %% [markdown]
# #### 2.1.1 - Radial Variance Transform
# xxx

# %%
import rvt # We import the radial variance method. Cite xxx
import skimage

# %%
#Apply Radial Variance Transform of image
rmin, rmax = 4, 25

def rvt_pipeline(data, rmin = 4, rmax = 25, th_scale = 0.3, min_distance = 5):
    
    #Apply Radial Variance Transform of image
    det = rvt.rvt(data[...,1], rmin = rmin, rmax = rmax)

    #Local max of the transformed image.
    blobs = skimage.feature.peak_local_max(det, min_distance=min_distance)
    blobs = np.stack([blobs[:,0], blobs[:,1]], axis=-1)

    #Extract detections that have a high enough value
    detections = []
    th = np.mean(det)*th_scale
    for blob in blobs:
        if np.mean(det[blob[0]-2:blob[0]+2, blob[1]-2:blob[1]+2]) > th:
            detections.append(blob)

    #Convert to numpy array and rename
    detections_rvt = np.array(detections)
    return detections_rvt

# %%
detections_rvt = rvt_pipeline(data, rmin = rmin, rmax = rmax, th_scale = 0.3)

# %% [markdown]
# #### 2.1.2 - Visualizing the detections from RVT
# xxx

# %%
plt.figure(figsize=(6,6))
plt.imshow(data[...,1], cmap="gray")
plt.scatter(detections_rvt[:,1], detections_rvt[:,0], s = 100, facecolors='none', edgecolors='r')
plt.title("Detections with Radial Variance Transform")
# Out:
# Text(0.5, 1.0, 'Detections with Radial Variance Transform')

# %% [markdown]
# ### 2.2 Detecting particles using LodeSTAR model
#
# xxx

# %% [markdown]
# #### 2.2.1  Prepare the Training Crop
# We will use a single crop of a single particle to train the neural network.

# %%
#### import matplotlib.patches as patches

crop_size = 40
labels_idx = 67

# We crop the image 6round the particle (based on the labels) - One could also use the detections or manually select a particle.
crop_x0 = int(labels[labels_idx, 0] - crop_size/2)
crop_y0 = int(labels[labels_idx, 1] - crop_size/2)

crop = data[crop_x0:crop_x0 + crop_size, crop_y0:crop_y0 + crop_size, :]
#crop=crop[::2,::2]
plt.figure(figsize=(9, 6))

plt.subplot(1, 2, 1)
plt.imshow(data[...,1], cmap="gray")
plt.colorbar()
plt.gca().add_patch(patches.Rectangle((crop_y0, crop_x0), crop_size, crop_size,
                                      linewidth=1, edgecolor="r",
                                      facecolor="none"))

plt.subplot(1, 2, 2)
plt.title("Crop around the particle")
plt.imshow(crop[...,1], cmap="gray")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 17
#      15 plt.imshow(data[...,1], cmap="gray")
#      16 plt.colorbar()
# ---> 17 plt.gca().add_patch(patches.Rectangle((crop_y0, crop_x0), crop_size, crop_size,
#      18                                       linewidth=1, edgecolor="r",
#      19                                       facecolor="none"))
#      21 plt.subplot(1, 2, 2)
#      22 plt.title("Crop around the particle")
#
# NameError: name 'patches' is not defined

# %%
x,y=np.meshgrid(np.arange(crop_size)-crop_size,np.arange(crop_size)-crop_size)

def grad(dx1,dx2,dy1,dy2):
    def inner(image):
        image[...,0]+=dx1*x+dy1*y
        image[...,1]+=dx2*x+dy2*y
        
        return image
    return inner

addgrad=dt.Lambda(grad,dx1=lambda: .02/40*np.random.randn(),dx2=lambda: .02/40*np.random.randn(),dy1=lambda: .02/40*np.random.randn(),dy2=lambda: .02/40*np.random.randn())

# %% [markdown]
# #### 2.2.1  Prepare pipeline and train model
# We will create a pipeline for training the LodeSTAR model

# %%
IMAGE_SIZE = 40
PADDING = 128
WAVELENGTH = 633e-9
RESOLUTION = 1.14e-7


#For z-propagation
crop_propagation_forward = dt.get_propagation_matrix((IMAGE_SIZE + PADDING, ) * 2, 1e-7, RESOLUTION, WAVELENGTH)
crop_propagation_backward = dt.get_propagation_matrix((IMAGE_SIZE + PADDING, ) * 2, -1e-7, RESOLUTION, WAVELENGTH)


##################################
import numpy as np
import torch

training_pipeline = (
    dt.Value(crop)
    >> dt.FourierTransform(padding=64) 
    >> dt.FourierTransformTransformation(crop_propagation_forward, crop_propagation_backward, lambda:np.random.randint(-10, 10)) 
    >> dt.InverseFourierTransform(padding=64) 
    >> dt.Multiply(lambda: np.random.uniform(0.1, 3))
    >> dt.Add(lambda: np.random.uniform(-0.2, 0.2))
    >> addgrad
    >> dt.Gaussian(sigma=lambda: np.random.rand() * 1e-3)
    >> dt.MoveAxis(-1, 0)
    >> dt.pytorch.ToTensor(dtype=torch.float32)
)

training_dataset = dt.pytorch.Dataset(training_pipeline, length=400, 
                                      replace=False)

# %%
plt.imshow(crop_propagation_forward.real)

# %%
dataloader = dl.DataLoader(training_dataset, batch_size=8, shuffle=True)

batch = next(iter(dataloader))
#Visualize a batch
plt.figure(figsize=(6, 3))
for i in range(8):
    plt.subplot(2, 4, i+1)
    plt.imshow(batch[0][i,1], cmap="gray")
    plt.axis("off")

# %%
lodestar = dl.LodeSTAR(n_transforms=4, optimizer=dl.Adam(lr=1e-4)).build()
trainer = dl.Trainer(max_epochs=400)
trainer.fit(lodestar, dataloader)
# Out:
# C:\Users\dmidt\anaconda3\envs\Deeplay\Lib\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[17], line 3
#       1 lodestar = dl.LodeSTAR(n_transforms=4, optimizer=dl.Adam(lr=1e-4)).build()
#       2 trainer = dl.Trainer(max_epochs=400)
# ----> 3 trainer.fit(lodestar, dataloader)
#
# File ~\anaconda3\envs\Deeplay\Lib\site-packages\lightning\pytorch\trainer\trainer.py:544, in Trainer.fit(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     542 self.state.status = TrainerStatus.RUNNING
#     543 self.training = True
# --> 544 call._call_and_handle_interrupt(
#     545     self, self._fit_impl, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path
#     546 )
#
# File ~\anaconda3\envs\Deeplay\Lib\site-packages\lightning\pytorch\trainer\call.py:44, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      42     if trainer.strategy.launcher is not None:
#      43         return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
# ---> 44     return trainer_fn(*args, **kwargs)
#      46 except _TunerExitException:
#      47     _call_teardown_hook(trainer)
#
# File ~\anaconda3\envs\Deeplay\Lib\site-packages\lightning\pytorch\trainer\trainer.py:580, in Trainer._fit_impl(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     573 assert self.state.fn is not None
#     574 ckpt_path = self._checkpoint_connector._select_ckpt_path(
#     575     self.state.fn,
#     576     ckpt_path,
#     577     model_provided=True,
#     578     model_connected=self.lightning_module is not None,
#     579 )
# --> 580 self._run(model, ckpt_path=ckpt_path)
#     582 assert self.state.stopped
#     583 self.training = False
#
# File ~\anaconda3\envs\Deeplay\Lib\site-packages\lightning\pytorch\trainer\trainer.py:963, in Trainer._run(self, model, ckpt_path)
#     960 self._logger_connector.reset_metrics()
#     962 # strategy will configure model and move it to the device
# --> 963 self.strategy.setup(self)
#     965 # hook
#     966 if self.state.fn == TrainerFn.FITTING:
#
# File ~\anaconda3\envs\Deeplay\Lib\site-packages\lightning\pytorch\strategies\strategy.py:155, in Strategy.setup(self, trainer)
#     152 # let the precision plugin convert the module here so that this strategy hook can decide the order
#     153 # of operations
#     154 self.model = self.precision_plugin.convert_module(self.model)
# --> 155 self.model_to_device()
#     156 self.model = self._setup_model(self.model)
#     158 if trainer.state.fn == TrainerFn.FITTING:
#
# File ~\anaconda3\envs\Deeplay\Lib\site-packages\lightning\pytorch\strategies\single_device.py:79, in SingleDeviceStrategy.model_to_device(self)
#      76 @override
#      77 def model_to_device(self) -> None:
#      78     assert self.model is not None, "self.model must be set before self.model.to()"
# ---> 79     self.model.to(self.root_device)
#
# File ~\anaconda3\envs\Deeplay\Lib\site-packages\lightning\fabric\utilities\device_dtype_mixin.py:55, in _DeviceDtypeModuleMixin.to(self, *args, **kwargs)
#      53 device, dtype = torch._C._nn._parse_to(*args, **kwargs)[:2]
#      54 _update_properties(self, device=device, dtype=dtype)
# ---> 55 return super().to(*args, **kwargs)
#
# File ~\anaconda3\envs\Deeplay\Lib\site-packages\torch\nn\modules\module.py:1152, in Module.to(self, *args, **kwargs)
#    1148         return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#    1149                     non_blocking, memory_format=convert_to_format)
#    1150     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
# -> 1152 return self._apply(convert)
#
# File ~\anaconda3\envs\Deeplay\Lib\site-packages\torch\nn\modules\module.py:802, in Module._apply(self, fn, recurse)
#     800 if recurse:
#     801     for module in self.children():
# --> 802         module._apply(fn)
#     804 def compute_should_use_set_data(tensor, tensor_applied):
#     805     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     806         # If the new tensor has compatible tensor type as the existing tensor,
#     807         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     812         # global flag to let the user control whether they want the future
#     813         # behavior of overwriting the existing tensor or not.
#
# File ~\anaconda3\envs\Deeplay\Lib\site-packages\torch\nn\modules\module.py:802, in Module._apply(self, fn, recurse)
#     800 if recurse:
#     801     for module in self.children():
# --> 802         module._apply(fn)
#     804 def compute_should_use_set_data(tensor, tensor_applied):
#     805     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     806         # If the new tensor has compatible tensor type as the existing tensor,
#     807         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     812         # global flag to let the user control whether they want the future
#     813         # behavior of overwriting the existing tensor or not.
#
#     [... skipping similar frames: Module._apply at line 802 (1 times)]
#
# File ~\anaconda3\envs\Deeplay\Lib\site-packages\torch\nn\modules\module.py:802, in Module._apply(self, fn, recurse)
#     800 if recurse:
#     801     for module in self.children():
# --> 802         module._apply(fn)
#     804 def compute_should_use_set_data(tensor, tensor_applied):
#     805     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     806         # If the new tensor has compatible tensor type as the existing tensor,
#     807         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     812         # global flag to let the user control whether they want the future
#     813         # behavior of overwriting the existing tensor or not.
#
# File ~\anaconda3\envs\Deeplay\Lib\site-packages\torch\nn\modules\module.py:825, in Module._apply(self, fn, recurse)
#     821 # Tensors stored in modules are graph leaves, and we don't want to
#     822 # track autograd history of `param_applied`, so we have to use
#     823 # `with torch.no_grad():`
#     824 with torch.no_grad():
# --> 825     param_applied = fn(param)
#     826 should_use_set_data = compute_should_use_set_data(param, param_applied)
#     827 if should_use_set_data:
#
# File ~\anaconda3\envs\Deeplay\Lib\site-packages\torch\nn\modules\module.py:1150, in Module.to.<locals>.convert(t)
#    1147 if convert_to_format is not None and t.dim() in (4, 5):
#    1148     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#    1149                 non_blocking, memory_format=convert_to_format)
# -> 1150 return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
#
# File ~\anaconda3\envs\Deeplay\Lib\site-packages\torch\nn\parameter.py:157, in UninitializedTensorMixin.__torch_function__(cls, func, types, args, kwargs)
#     155     if kwargs is None:
#     156         kwargs = {}
# --> 157     return super().__torch_function__(func, types, args, kwargs)
#     158 raise ValueError(
#     159     f'Attempted to use an uninitialized parameter in {func}. '
#     160     'This error happens when you are using a `LazyModule` or '
#     161     f'explicitly manipulating `torch.nn.parameter.{cls.__name__}` '
#     162     'objects. When using LazyModules Call `forward` with a dummy batch '
#     163     'to initialize the parameters before calling torch functions')
#
# RuntimeError: CUDA error: out of memory
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %% [markdown]
# #### 2.2.1  Visualize result from trained LodeSTAR model
#
# xxx

# %%
torch_image = torch.from_numpy(data).permute(2, 0, 1).unsqueeze(0).float()
prediction = lodestar(torch_image)[0].cpu().detach().numpy()
x, y, rho = prediction[0], prediction[1], prediction[-1]

plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.title("Brightfield data (imaginary part)")
plt.imshow(data[...,1], cmap="gray")
plt.axis("off")

plt.subplot(1, 3, 2)
plt.title("LodeSTAR prediction")
plt.imshow(rho, cmap="gray")
plt.axis("off")

plt.subplot(1, 3, 3)
plt.title("LodeSTAR prediction with detections")
plt.imshow(data[...,1], cmap="gray")
plt.scatter(y.flatten(), x.flatten(), alpha=rho.flatten() / rho.max(), s=5)
plt.axis("off")

plt.show()

# %%
alpha = 0.5
beta = 0.5
cutoff = 0.90
mode = "quantile"#"constant"

plt.figure(figsize=(6, 6))
torch_image = torch.from_numpy(data).permute(2, 0, 1).unsqueeze(0).float()
detections = lodestar.detect(torch_image, alpha=alpha, beta=beta, 
                                mode=mode, cutoff=cutoff)[0]

plt.imshow(data[...,1], cmap="gray")
plt.scatter(detections[:,1], detections[:,0], s = 100, facecolors='none', edgecolors='r')
plt.axis("off")

plt.show()

# %% [markdown]
# ### 2.3 Comparison between LodeSTAR and Radial Variance Transform
#
# Both methods have a dependence on the threshold chosen. Down below we analyze the True Positive(TP), False Positive(FP), False Negative(FN) and the F1 Score, as well as constructing a ROC curve.
#
# Obs, we denote that there are more dependencies outside the threshold and a gridsearch might give more accurate insights.

# %%
radius = 6 # Radius of the particle in pixels
centroids = labels[:, :2] # We use the labels as the ground truth
n_values = 50 # Number of values to test the threshold

# We create the arrays to store the results
TP_l, FP_l, FN_l, TN_l, F1_l = np.zeros(n_values), np.zeros(n_values), np.zeros(n_values), np.zeros(n_values), np.zeros(n_values)
TP_c, FP_c, FN_c, TN_c, F1_c = np.zeros(n_values), np.zeros(n_values), np.zeros(n_values), np.zeros(n_values), np.zeros(n_values)
mask = np.zeros_like(data[...,1])

# %%
def add_bin_circles(positions, radius, image):
    """Add circles to an image."""
    im = image.copy()
    for position in positions:
        rr, cc = skimage.draw.disk(position, radius)
        im[rr, cc] = 1
    return im

# %%
GT_particles = add_bin_circles(centroids, radius, mask)

# %%
plt.figure(figsize=(4, 4))
plt.imshow(GT_particles, cmap="gray")
plt.axis("off")
plt.title("Ground truth particles")
# Out:
# Text(0.5, 1.0, 'Ground truth particles')

# %%
### For LodeSTAR
cutoff_values_l = np.linspace(0.9, 1, n_values)

alpha = 0.5
beta = 0.3
mode = "quantile"

for i, cutoff in enumerate(cutoff_values_l):
    if i % 50 == 0 and i > 0: 
        print(f"Testing cutoff {i}/{n_values}")
    
    torch_image = torch.from_numpy(data).permute(2, 0, 1).unsqueeze(0).float()
    detections = lodestar.detect(torch_image, alpha=alpha, beta=beta,
                                    mode=mode, cutoff=cutoff)[0]

    #Remove detections that are too close to the border with size radius
    detections = detections[(detections[:,0] > radius) & (detections[:,0] < data.shape[0] - radius) & 
                            (detections[:,1] > radius) & (detections[:,1] < data.shape[1] - radius)]

    # We create the mask with the detections
    mask_tmp = add_bin_circles(detections, radius, mask)

    # True positives - Overlap between the mask and the ground truth
    TP = np.sum(mask_tmp * GT_particles)
    # False positives - Detections that are not in the ground truth
    FP = np.sum(mask_tmp) - TP
    # False negatives - Ground truth particles that were not detected
    FN = np.sum(GT_particles) - TP
    # True negatives - Background that is correctly classified
    TN = np.sum((1 - mask_tmp) * (1 - GT_particles))
    # F1 score
    F1 = 2 * TP / (2 * TP + FP + FN)

    TP_l[i] = TP
    FP_l[i] = FP
    FN_l[i] = FN
    TN_l[i] = TN
    F1_l[i] = F1

# %%
i
# Out:
# 49

# %%
### For RVT
cutoff_values_c = np.linspace(-0.5, 6, n_values)

for i, cutoff in enumerate(cutoff_values_c):
    if i % 50 == 0 and i > 0 : 
        print(f"Testing cutoff {i}/{n_values}")

    detections = rvt_pipeline(data, rmin = rmin, rmax = rmax, th_scale = cutoff)

    #Remove detections that are too close to the border with size radius
    detections = detections[(detections[:,0] > radius) & (detections[:,0] < data.shape[0] - radius) & 
                            (detections[:,1] > radius) & (detections[:,1] < data.shape[1] - radius)]

    # We create the mask with the detections
    mask_tmp = add_bin_circles(detections, radius, mask)

    # True positives - Overlap between the mask and the ground truth
    TP = np.sum(mask_tmp * GT_particles)
    # False positives - Detections that are not in the ground truth
    FP = np.sum(mask_tmp) - TP
    # False negatives - Ground truth particles that were not detected
    FN = np.sum(GT_particles) - TP
    # True negatives - Background that is correctly classified
    TN = np.sum((1 - mask_tmp) * (1 - GT_particles))
    # F1 score
    F1 = 2 * TP / (2 * TP + FP + FN)

    TP_c[i] = TP
    FP_c[i] = FP
    FN_c[i] = FN
    TN_c[i] = TN
    F1_c[i] = F1

# %%
# ROC
TPR_l = TP_l / (TP_l + FN_l)
FPR_l = FP_l / (FP_l + TN_l)

TPR_c = TP_c / (TP_c + FN_c)
FPR_c = FP_c / (FP_c + TN_c)

plt.figure(figsize=(6, 6))
plt.plot(FPR_l, TPR_l, label="LodeSTAR", linestyle="-", color = 'darkblue', linewidth=4)
plt.plot(FPR_c, TPR_c, label="RVT", linestyle="-", color = 'darkorange', linewidth=4)
plt.plot([0, 1], [0, 1], linestyle="--", color="gray", label="Random Classifier", linewidth=4, alpha = 0.5)
plt.xlim(-0.01, 1.01)
plt.ylim(-0.01, 1.01)
plt.legend(fontsize=14)
plt.xlabel("False Positive Rate", fontsize=14) 
plt.ylabel("True Positive Rate", fontsize=14)
plt.title("ROC curve", fontsize=16)
plt.show()

# %%
# F1 score
plt.figure(figsize=(6, 6))
plt.plot(np.arange(n_values), F1_l, label="LodeSTAR", linestyle="-", color = 'darkblue', linewidth=4)
plt.plot(np.arange(n_values), F1_c, label="RVT", linestyle="-", color = 'darkorange', linewidth=4)
plt.legend(fontsize=14)
plt.xlabel("Threshold (range)", fontsize=14)
plt.ylabel("F1 score", fontsize=14)
plt.title("F1 score", fontsize=16)
plt.show()

# %%
#Find the best threshold for LodeSTAR
idx_l = np.argmax(F1_l)
best_threshold_l = cutoff_values_l[idx_l]
print(f"Best threshold for LodeSTAR: {best_threshold_l}")
print(f"Best F1 score for LodeSTAR: {F1_l[idx_l]}")

#Find the best threshold for RVT
idx_c = np.argmax(F1_c)
best_threshold_c = cutoff_values_c[idx_c]
print(f"Best threshold for RVT: {best_threshold_c}")
print(f"Best F1 score for RVT: {F1_c[idx_c]}")
# Out:
# Best threshold for LodeSTAR: 0.9979591836734694
# Best F1 score for LodeSTAR: 0.4439284593661751
# Best threshold for RVT: 2.285714285714286
# Best F1 score for RVT: 0.2813337621957757

# %% [markdown]
# #### 2.3.1 Comparison between LodeSTAR and Radial Variance Transform - On individual ROIs
#
# xxx

# %%
def get_rois(data, positions, padsize):
    """Function for retrieving ROIs from data. Obs - rounded to integers"""

    rois = []
    for pos in positions:
        #Check if the roi is out of bounds
        if pos[1]-padsize < 0 or pos[1]+padsize >= data.shape[0] or pos[0]-padsize < 0 or pos[0]+padsize >= data.shape[1]:
            continue

        roi = data[int(pos[0]-padsize):int(pos[0]+padsize), int(pos[1]-padsize):int(pos[1]+padsize),:]
        
        rois.append(roi)
    return np.stack(rois)

# %%
padsize = 20
rois = get_rois(data, centroids, padsize)

# %%
detections_rvt_rois = [rvt_pipeline(roi, rmin = rmin, rmax = rmax, th_scale = best_threshold_c) for roi in rois]

#If more than 1 detection, take out the one closest to center
detections_rvt_rois_new = []
for detections in detections_rvt_rois:
    if len(detections) > 1:
        distances = np.linalg.norm(detections - padsize, axis=1)
        detections = detections[np.argmin(distances)]
    detections_rvt_rois_new.append(detections)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 detections_rvt_rois = [rvt_pipeline(roi, rmin = rmin, rmax = rmax, th_scale = best_threshold_c) for roi in rois]
#       3 #If more than 1 detection, take out the one closest to center
#       4 detections_rvt_rois_new = []
#
# Cell In[16], line 1, in <listcomp>(.0)
# ----> 1 detections_rvt_rois = [rvt_pipeline(roi, rmin = rmin, rmax = rmax, th_scale = best_threshold_c) for roi in rois]
#       3 #If more than 1 detection, take out the one closest to center
#       4 detections_rvt_rois_new = []
#
# NameError: name 'best_threshold_c' is not defined

# %%
detections_lodestar_rois = []

for roi in rois:
    torch_image = torch.from_numpy(roi).permute(2, 0, 1).unsqueeze(0).float()
    detections = lodestar.detect(torch_image, alpha=alpha, beta=beta, 
                                    mode=mode, cutoff=best_threshold_l)[0].astype(int)
    detections_lodestar_rois.append(detections)

#If more than 1 detection, take out the one closest to center
detections_lodestar_rois_new = []
for detections in detections_lodestar_rois:
    if len(detections) > 1:
        distances = np.linalg.norm(detections - padsize, axis=1)
        detections = detections[np.argmin(distances)]
    detections_lodestar_rois_new.append(detections)
# Out:
# C:\Users\dmidt\anaconda3\envs\Deeplay\Lib\site-packages\scipy\signal\_signaltools.py:279: RuntimeWarning: invalid value encountered in cast
#   z = _sigtools._correlateND(in1zpadded, in2, out, val)

# %%
th_pixels = 3

# %%
#Count how many particles that are correctly identified
correct_rvt = 0
for detection_rvt in detections_rvt_rois_new:
    if np.linalg.norm(detection_rvt - padsize) < th_pixels:
        correct_rvt += 1

correct_lodestar = 0
for detection_lodestar in detections_lodestar_rois_new:
    if np.linalg.norm(detection_lodestar - padsize) < th_pixels:
        correct_lodestar += 1

# %%
print(f"Correctly identified RVT: {correct_rvt}/{len(rois)} ({np.round(correct_rvt/len(rois)*100, 1)})%")
print(f"Correctly identified LodeSTAR: {correct_lodestar}/{len(rois)} ({np.round(correct_lodestar/len(rois)*100, 1)})%")
# Out:
# Correctly identified RVT: 22/82 (26.8)%
# Correctly identified LodeSTAR: 49/82 (59.8)%

# %% [markdown]
# ## 3 - Quantification of particle properties in Brightfield
#
# xxx

# %%
padsize = 20
positions  = labels[:, :2] # We use the labels as the ground truth

#Extract positions that are not too close to the border
arg1 = (positions[:,0] > padsize) & (positions[:,0] < data.shape[0] - padsize) & (positions[:,1] > padsize) & (positions[:,1] < data.shape[1] - padsize)
positions = positions[arg1]

#Extract positions that do not overlap to close to eachother
distances = np.linalg.norm(positions[:, None] - positions, axis=-1)
arg2 = np.sum(distances < padsize*1.5, axis=0) == 1

#Extract the positions
positions = positions[arg2]

#Extract the labels
labels = labels[arg1][arg2]

# %%
rois = get_rois(data, positions, padsize)
rois.shape
# Out:
# (40, 40, 40, 2)

# %%
plt.figure(figsize=(6, 3))
for i in range(8):
    plt.subplot(2, 4, i+1)
    plt.imshow(rois[i,...,1], cmap="gray")
    plt.axis("off")

# %% [markdown]
# ### 3.1 Quantifying particle signal with a classical method
#
# Gaussian fit

# %%
# Do a gaussian fit to the data and summarize the ROI
import numpy as np
from scipy.stats import norm
from scipy.stats import multivariate_normal
import scipy
def gaussian_fit_and_sum(input_data):
    """Fit a 2D Gaussian distribution to the data."""
    # Get the dimensions of the image
    height, width = input_data.shape

    # Create meshgrid for the image coordinates
    x, y = np.meshgrid(np.arange(0, width)-width/2, np.arange(0, height)-height/2)

    # Stack the meshgrid coordinates
    data = np.column_stack((x.flatten(), y.flatten()))

    # Fit a 2D Gaussian distribution to the pixel intensity values
    fitf=lambda x,a,b,c,d,e: a*np.exp(-((x[:,0]-b)**2+(x[:,1]-c)**2)/(2*d**2))+e

    f=scipy.optimize.curve_fit(fitf,data,input_data.flatten()-np.mean(input_data.flatten()),p0=[1,0,0,1,0],bounds=((-1,-5,-5,.1,-1),((1,5,5,100,1))))
    #mean = np.mean(data, axis=0)
    #cov = np.cov(data, rowvar=False)
    # Create a multivariate Gaussian distribution using the fitted parameters
    #gaussian_distribution = multivariate_normal(mean=mean, cov=cov)

    # Evaluate the Gaussian distribution for each pixel value
    #gaussian_values = gaussian_distribution.pdf(data)

    # Reshape the Gaussian values to the original image shape
    #gaussian_values = gaussian_values.reshape((height, width))

    # Sum the pixel values weighted by the Gaussian values
    weighted_sum = f[0][0]*f[0][3]**2#np.sum(input_data * gaussian_values)

    return weighted_sum

# %%
signal_sum_gauss = np.array([gaussian_fit_and_sum(roi[...,1]) for roi in rois])

# %%
def get_polarizability(radius, refractive_index):
    """Calculate the polarizability of a particle."""
    return np.array(4/3 * np.pi * radius**3 * (refractive_index - 1.33))

# %%
polarizabilities = get_polarizability(labels[:,3], labels[:,4])

# %%
plt.figure(figsize=(6, 6))
plt.scatter(polarizabilities, np.abs(signal_sum_gauss), color="darkblue", alpha=0.6, s=50)
#line fit
coefficients = np.polyfit(polarizabilities, np.abs(signal_sum_gauss), 1)
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(polarizabilities.min(), polarizabilities.max(), 100)
y_axis = polynomial(x_axis)
plt.plot(x_axis, y_axis, color="red", linestyle="--", linewidth=2, label="Linear fit")
plt.xlabel("Polarizability", fontsize=14)
plt.ylabel("Signal sum gauss", fontsize=14)
plt.legend()
plt.title("Polarizability vs. Signal with gaussian fit")
# Out:
# Text(0.5, 1.0, 'Polarizability vs. Signal with gaussian fit')

# %%
#Find linear fit that converts signal to polarizability
coefficients = np.polyfit(np.abs(signal_sum_gauss), polarizabilities, 1)
polynomial = np.poly1d(coefficients)

#Predict the polarizabilities
polarizabilities_pred = polynomial(np.abs(signal_sum_gauss))

#Compute MSE, MAE
mse_g = np.mean((polarizabilities - polarizabilities_pred)**2)
mae_g = np.mean(np.abs(polarizabilities - polarizabilities_pred))

print(f"MSE: {mse_g}")
print(f"MAE: {mae_g}")
# Out:
# MSE: 2.6625696138514558e-43
# MAE: 3.5914587455035964e-22

# %% [markdown]
# ### 3.2 Quantifying particle signal using a 2DCNN

# %% [markdown]
# #### 3.2.1 Defining the optical system
#
# xxx

# %%
IMAGE_SIZE = 40
NA = 1.3
MAGNIFICATION = 1
WAVELENGTH = 633e-9
RESOLUTION = 1.14e-7

# %%
def crop(pupil_radius):
    def inner(image):
        x = np.arange(image.shape[0]) - image.shape[0] / 2
        y = np.arange(image.shape[1]) - image.shape[1] / 2
        X, Y = np.meshgrid(x, y)
        image[X ** 2 + Y ** 2 > pupil_radius ** 2] = 0
        return image
    return inner
CROP = dt.Lambda(crop, pupil_radius=lambda: 0.7*IMAGE_SIZE)
HC = dt.HorizontalComa(coefficient=lambda c1: c1, c1=0 + np.random.randn() * .35)
VC = dt.VerticalComa(coefficient=lambda c2:c2, c2=0 + np.random.randn() * .35)
optics = dt.Brightfield(
    NA=NA,
    magnification=MAGNIFICATION,
    wavelength=WAVELENGTH,
    resolution=RESOLUTION,
    return_field=True, 
    output_region=(0, 0, IMAGE_SIZE, IMAGE_SIZE),pupil=CROP>>VC>>HC
)

# %% [markdown]
# #### 3.2.2 Defining the particle(s)

# %%
RADIUS_RANGE = (25e-9, 150e-9)
REFRACTIVE_INDEX_RANGE = (1.37, 1.6)

# %%
particle = dt.MieSphere(
    position=lambda: (IMAGE_SIZE / 2, IMAGE_SIZE / 2) + np.random.rand(2) * 4 - 2,
    z=lambda: np.random.randn() * 5,
    radius=lambda:np.random.uniform(*RADIUS_RANGE),
    refractive_index=lambda: np.random.uniform(*REFRACTIVE_INDEX_RANGE),
    L=8,
    position_unit="pixel",
)

# %% [markdown]
# #### 3.2.3 Create dataset of particles

# %% [markdown]
# The noise is simulated as gaussian distributed noise, with independent real and imaginary parts. The amplitude of the noise is determined by the dummy property `level`, which is explicitly shared between the two features. Finally, the real and imaginary parts of the field are separated into two layers, and the plane wave is subtracted.

# %%
real_noise = dt.Gaussian(
    mu=0, 
    sigma=lambda: np.random.rand() * 0.05,
)

noise = real_noise >> dt.Gaussian(
    mu=0, 
    sigma=lambda real_sigma: real_sigma * 0.05j,
    real_sigma=real_noise.sigma
)

def func():
    def inner(image):
        image = image - 1
        output = np.zeros((*image.shape[:2], 2))
        output[..., 0:1] = np.real(image)
        output[..., 1:2] = np.imag(image)
        return output
    return inner


complex_to_float = dt.Lambda(func)

# %% [markdown]
# We now define how these objects combine. Note that the noise is added inside the optics. This means that it will have the same PSF as the sample, which is what is observed.

# %%
noisy_dataset = optics(particle >> noise) >>dt.Gaussian(sigma=0.002)>>dt.Gaussian(sigma=0.002j) >> complex_to_float>>addgrad
clean_dataset = optics(particle) >> complex_to_float

dataset = noisy_dataset & clean_dataset

# %%
#3x3 grid of augmented images
plt.figure(figsize=(4, 4))
for i in range(9):
    plt.subplot(3, 3, i+1)
    img = dataset.update().resolve()
    plt.imshow(img[0][...,1], cmap="gray")
    plt.axis('off')

# %% [markdown]
# #### 3.2.4 Defining the training label
#
# We extract the parameters we want the network to learn. This is the integrated signal.

# %%
def get_label():
    "Label function for the dataset. We sum the imaginary part of the image."
    def inner(image):
        return np.expand_dims(np.array(10*np.sum(image[...,1])), -1)
    return inner

# %%
def get_polarizability(image):
    r = image[0].get_property("radius")
    n = image[0].get_property("refractive_index") - 1.33
    return np.array(4/3 * np.pi * r**3 * n)

# %%
def batch_function(image):
    return 10*np.array(image[0])

# %% [markdown]
# #### 3.2.5 Defining quantification model (2DCNN)
# xxx

# %%
conv = dl.ConvolutionalNeuralNetwork(
    in_channels = 2, 
    hidden_channels=[16, 32], 
    out_channels = 64,
    pool = dl.torch.nn.MaxPool2d(kernel_size=2),
    out_activation=dl.torch.nn.ReLU
    )

mlp = dl.MultiLayerPerceptron(None, [32, 32], 1)

net = dl.Sequential(
    conv,
    mlp
)

# %%
regressor = dl.Regressor(
    model=net,
    loss=dl.torch.nn.MSELoss(),
    optimizer=dl.Adam(),
)
cnn_regressor = regressor.create()

# %% [markdown]
# #### 3.2.6 Training of the model
# xxx

# %%
image_and_signal_pipeline = noisy_dataset &  clean_dataset >> dt.Lambda(get_label)

# %%
training_dataset = dt.pytorch.Dataset(image_and_signal_pipeline, length=1000, 
                                      replace=False)

dataloader = dl.DataLoader(training_dataset, batch_size=16, shuffle=True)

# %%
batch = next(iter(dataloader))
#Visualize a batch
plt.figure(figsize=(6, 3))
for i in range(8):
    plt.subplot(2, 4, i+1)
    plt.imshow(batch[0][i,0], cmap="gray")
    plt.colorbar()
    plt.axis("off")

# %%
trainer = dl.Trainer(max_epochs=200)
trainer.fit(cnn_regressor, dataloader)
# Out:
# C:\Users\dmidt\anaconda3\envs\Deeplay\Lib\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
# ┏━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name          ┃ Type             ┃ Params ┃ Mode  ┃
# ┡━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━┩
# │ 0 │ loss          │ MSELoss          │      0 │ train │
# │ 1 │ train_metrics │ MetricCollection │      0 │ train │
# │ 2 │ val_metrics   │ MetricCollection │      0 │ train │
# │ 3 │ test_metrics  │ MetricCollection │      0 │ train │
# │ 4 │ model         │ Sequential       │ 24.5 K │ train │
# │ 5 │ optimizer     │ Adam             │      0 │ train │
# └───┴───────────────┴──────────────────┴────────┴───────┘
# Trainable params: 24.5 K
# Non-trainable params: 0
# Total params: 24.5 K
# Total estimated model params size (MB): 0
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %% [markdown]
# #### 3.2.7 Validating the model on simulated data and ROIs from frame.
# xxx

# %%
#Generate new data.
val_dataset = dt.pytorch.Dataset(image_and_signal_pipeline, length=200)
val_dataloader = dl.DataLoader(val_dataset, batch_size=16, shuffle=True)

#Predict the signal
predictions = []
labels_ = []
for batch in val_dataloader:
    predictions.append(cnn_regressor(batch[0]).detach().numpy())
    labels_.append(batch[1].detach().numpy())

#Concatenate the predictions and labels
predictions = np.concatenate(predictions)[:, 0]
labels_ = np.concatenate(labels_)[:, 0]

# %%
#Scatterplot of the predicted signal vs the true signal
plt.figure(figsize=(6, 6))
plt.scatter(labels_, predictions, color="darkblue", alpha=0.6, s=50)
#line fit
coefficients = np.polyfit(labels_, predictions, 1)
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(labels_.min(), predictions.max(), 100)
y_axis = polynomial(x_axis)
plt.plot(x_axis, y_axis, color="red", linestyle="--", linewidth=2, label="Linear fit")
plt.xlabel("True signal", fontsize=14)
plt.ylabel("Predicted signal", fontsize=14)
plt.legend()
plt.title("True signal vs Predicted signal", fontsize=16)
plt.show()

# %%
#Predict on the rois
import torch
predictions_rois = [cnn_regressor(torch.from_numpy(roi-np.median(roi,axis=(1,2),keepdims=True)).permute(2, 0, 1).unsqueeze(0).float()) for roi in rois]
predictions_rois = np.array([pred.detach().numpy()[0, 0] for pred in predictions_rois])

# %%
polarizabilities_rois = get_polarizability(labels[:,3], labels[:,4])

# %%
plt.figure(figsize=(6, 6))
plt.scatter(polarizabilities_rois, np.abs(predictions_rois), color="darkblue", alpha=0.6, s=50)
#line fit
coefficients = np.polyfit(polarizabilities_rois, np.abs(predictions_rois), 1)
polynomial = np.poly1d(coefficients)
x_axis = np.linspace(polarizabilities_rois.min(), polarizabilities_rois.max(), 100)
y_axis = polynomial(x_axis)
plt.plot(x_axis, y_axis, color="red", linestyle="--", linewidth=2, label="Linear fit")
plt.xlabel("Polarizability", fontsize=14)
plt.ylabel("Signal prediction with CNN", fontsize=14)
plt.legend()
plt.title("Polarizability vs. Signal predicted with CNN")
# Out:
# Text(0.5, 1.0, 'Polarizability vs. Signal predicted with CNN')

# %%
# Find linear fit that converts signal to polarizability
coefficients = np.polyfit(np.abs(predictions_rois), polarizabilities_rois, 1)
polynomial = np.poly1d(coefficients)

# Predict the polarizabilities
polarizabilities_pred = polynomial(np.abs(predictions_rois))

# Compute MSE, MAE
mse_cnn = np.mean((polarizabilities_rois - polarizabilities_pred)**2)
mae_cnn = np.mean(np.abs(polarizabilities_rois - polarizabilities_pred))

print(f"MSE: {mse_cnn}")
print(f"MAE: {mae_cnn}")
# Out:
# MSE: 4.0637655465419695e-44
# MAE: 1.5855773504450869e-22

# %%
#Compare the MSE and MAE of the two methods
print(f"MSE Gaussian: {mse_g}")
print(f"MAE Gaussian: {mae_g}")
print(f"MSE CNN: {mse_cnn}")
print(f"MAE CNN: {mae_cnn}")
# Out:
# MSE Gaussian: 2.6625696138514558e-43
# MAE Gaussian: 3.5914587455035964e-22
# MSE CNN: 4.0637655465419695e-44
# MAE CNN: 1.5855773504450869e-22

# %% [markdown]
# ### 3.3 Investigating the dependence of noise

# %% [markdown]
# ### 3.4 Investigating the signal as adependence on refractive index and radius

# %% [markdown]
# #### 3.4.1 Fix refractive index

# %%
FIX_RI = 1.4
RADIUS_RANGE = (25e-9, 200e-9)
samples_per_case = 10

NOISY = []
CLEAN = []

for i, rad in enumerate(np.linspace(*RADIUS_RANGE, 100)):
    if i % 10 == 0:
        print(f"Currently at {i}/100")

    particle = dt.MieSphere(
        position=lambda: (IMAGE_SIZE / 2, IMAGE_SIZE / 2) + np.random.rand(2) * 4 - 2,
        z=lambda: np.random.randn() * 5,
        radius=lambda: rad,
        refractive_index=lambda: FIX_RI,
        L=8,
        position_unit="pixel",
    )

    #Define the noise and optical system
    noisy_dataset = optics(particle >> noise) >>dt.Gaussian(sigma=0.002)>>dt.Gaussian(sigma=0.002j) >> complex_to_float>>addgrad
    clean_dataset = optics(particle) >> complex_to_float

    dataset = noisy_dataset & clean_dataset

    #Get
    images = [dataset.update().resolve() for _ in range(samples_per_case)]

    noisy = np.stack([img[0] for img in images])
    clean = np.stack([img[1] for img in images])

    NOISY.append(noisy)
    CLEAN.append(clean)

NOISY = np.concatenate(NOISY)
CLEAN = np.concatenate(CLEAN)
# Out:
# Currently at 0/100
# Currently at 10/100
# Currently at 20/100
# Currently at 30/100
# Currently at 40/100
# Currently at 50/100
# Currently at 60/100
# Currently at 70/100
# Currently at 80/100
# Currently at 90/100

# %%
signal_sum_gauss_fix_ri = np.abs(np.array([gaussian_fit_and_sum(roi[...,1]) for roi in CLEAN]))

# %%
signal_sum_cnn_fix_ri = np.abs(cnn_regressor(torch.from_numpy(CLEAN).permute(0, 3, 1, 2).float()).detach().numpy()[:, 0])

# %%
#Normalize the signals
signal_sum_gauss_fix_ri = (signal_sum_gauss_fix_ri) / (signal_sum_gauss_fix_ri.mean() - 0*signal_sum_gauss_fix_ri.min())
signal_sum_cnn_fix_ri = (signal_sum_cnn_fix_ri) / (signal_sum_cnn_fix_ri.mean() - 0*signal_sum_cnn_fix_ri.min())

# %%
rii = np.concatenate([np.repeat(x, 10) for x in np.linspace(*RADIUS_RANGE, 100)])*1e9

# %%
theoretical_pol = get_polarizability(rii*1e-9, FIX_RI)

#Normalize the polarizabilities
theoretical_pol = (theoretical_pol) / (theoretical_pol.mean())

# %%
#X-axis for radius and signal on y-axis
plt.figure(figsize=(6, 6))
plt.scatter(rii, signal_sum_gauss_fix_ri, color="darkblue", alpha=0.3, s=20, label="Gaussian fit")
plt.scatter(rii, signal_sum_cnn_fix_ri, color="darkred", alpha=0.3, s=20, label="CNN prediction")
#plt.scatter(rii, theoretical_pol, color="darkgreen", alpha=0.3, s=20, label="Theoretical polarizability")

x_axis = np.linspace(25, 200, 100)
#Polynomial line for gauss
coefficients = np.polyfit(rii, signal_sum_gauss_fix_ri, 3)
polynomial = np.poly1d(coefficients)
y_axis = polynomial(x_axis)
plt.plot(x_axis, y_axis, linestyle="--", linewidth=3, label="Gaussian fit")

#Polynomial line for CNN
coefficients = np.polyfit(rii, signal_sum_cnn_fix_ri, 3)
polynomial = np.poly1d(coefficients)
y_axis = polynomial(x_axis)
plt.plot(x_axis, y_axis, linestyle="--", linewidth=3, label="CNN prediction")

#Polynomial line for theoretical
coefficients = np.polyfit(rii, theoretical_pol, 3)
polynomial = np.poly1d(coefficients)
y_axis = polynomial(x_axis)
plt.plot(x_axis, y_axis, linestyle="--", linewidth=3, label="Theoretical polarizability (normalized)")

#set xticks
plt.xticks([0, 50, 100, 150, 200], labels=[f"{x:.0f}" for x in [0, 50, 100, 150, 200]])

plt.xlabel("Radius(nm)", fontsize=14)
plt.ylabel("Normalized Signal", fontsize=14)
plt.yscale('log')
plt.xscale('log')

plt.legend()
plt.title("Radius vs. Signal while keeping RI constant", fontsize=16)
# Out:
# Text(0.5, 1.0, 'Radius vs. Signal while keeping RI constant')

# %% [markdown]
# #### 3.4.1 Fix radius

# %%
RI_RANGE = (1.37, 1.6)
FIX_RADIUS = 150e-9
samples_per_case = 10

NOISY = []
CLEAN = []

for i, ri in enumerate(np.linspace(*RI_RANGE, 100)):
    if i % 10 == 0:
        print(f"Currently at {i}/100")

    particle = dt.MieSphere(
        position=lambda: (IMAGE_SIZE / 2, IMAGE_SIZE / 2) + np.random.rand(2) * 4 - 2,
        z=lambda: np.random.randn() * 5,
        radius=lambda: FIX_RADIUS,
        refractive_index=lambda: ri,
        L=8,
        position_unit="pixel",
    )

    #Define the noise and optical system
    noisy_dataset = optics(particle >> noise) >> complex_to_float
    clean_dataset = optics(particle) >> complex_to_float

    dataset = noisy_dataset & clean_dataset

    #Get
    images = [dataset.update().resolve() for _ in range(samples_per_case)]

    noisy = np.stack([img[0] for img in images])
    clean = np.stack([img[1] for img in images])

    NOISY.append(noisy)
    CLEAN.append(clean)

NOISY = np.concatenate(NOISY)
CLEAN = np.concatenate(CLEAN)
# Out:
# Currently at 0/100
# Currently at 10/100
# Currently at 20/100
# Currently at 30/100
# Currently at 40/100
# Currently at 50/100
# Currently at 60/100
# Currently at 70/100
# Currently at 80/100
# Currently at 90/100

# %%
signal_sum_gauss_fix_ri = np.abs(np.array([gaussian_fit_and_sum(roi[...,1]) for roi in CLEAN]))

# %%
signal_sum_cnn_fix_ri = np.abs(cnn_regressor(torch.from_numpy(CLEAN).permute(0, 3, 1, 2).float()).detach().numpy()[:, 0])

# %%
#Normalize the signals
signal_sum_gauss_fix_ri = (signal_sum_gauss_fix_ri - signal_sum_gauss_fix_ri.min()) / (signal_sum_gauss_fix_ri.max() - signal_sum_gauss_fix_ri.min())
signal_sum_cnn_fix_ri = (signal_sum_cnn_fix_ri - signal_sum_cnn_fix_ri.min()) / (signal_sum_cnn_fix_ri.max() - signal_sum_cnn_fix_ri.min())

# %%
rii = np.concatenate([np.repeat(x, 10) for x in np.linspace(*RI_RANGE, 100)])

# %%
theoretical_pol = get_polarizability(FIX_RADIUS, rii)

#Normalize the polarizabilities
theoretical_pol = (theoretical_pol - theoretical_pol.min()) / (theoretical_pol.max() - theoretical_pol.min())

# %%
#X-axis for radius and signal on y-axis
plt.figure(figsize=(6, 6))
plt.scatter(rii, signal_sum_gauss_fix_ri, color="darkblue", alpha=0.3, s=20, label="Gaussian fit")
plt.scatter(rii, signal_sum_cnn_fix_ri, color="darkred", alpha=0.3, s=20, label="CNN prediction")
#plt.scatter(rii, theoretical_pol, color="darkgreen", alpha=0.3, s=20, label="Theoretical polarizability")

x_axis = np.linspace(1.37, 1.6,  100)
#Polynomial line for gauss
coefficients = np.polyfit(rii, signal_sum_gauss_fix_ri, 3)
polynomial = np.poly1d(coefficients)
y_axis = polynomial(x_axis)
plt.plot(x_axis, y_axis, linestyle="--", linewidth=3, label="Gaussian fit")

#Polynomial line for CNN
coefficients = np.polyfit(rii, signal_sum_cnn_fix_ri, 3)
polynomial = np.poly1d(coefficients)
y_axis = polynomial(x_axis)
plt.plot(x_axis, y_axis, linestyle="--", linewidth=3, label="CNN prediction")

#Polynomial line for theoretical
coefficients = np.polyfit(rii, theoretical_pol, 3)
polynomial = np.poly1d(coefficients)
y_axis = polynomial(x_axis)
plt.plot(x_axis, y_axis, linestyle="--", linewidth=3, label="Theoretical polarizability (normalized)")

#set xticks
#plt.xticks([0, 50, 100, 150, 200], labels=[f"{x:.0f}" for x in [0, 50, 100, 150, 200]])

plt.xlabel("Radius(nm)", fontsize=14)
plt.ylabel("Normalized Signal", fontsize=14)
plt.legend()
plt.title("RI vs. Signal while keeping Radius constant", fontsize=16)
# Out:
# Text(0.5, 1.0, 'RI vs. Signal while keeping Radius constant')

# %% [markdown]
# ## 4. Combining detection and quantification in brightfield
